# %%
#ParsingHLA
import csv
import pandas as pd 

genesHLA = {}

# Change current working directory 
loc = ("/Users/anamikabasu/Desktop/AFND0003326.csv") 

df = pd.read_csv("/Users/anamikabasu/Desktop/AFND0003326.csv",header=None)

for row in range(0,len(df.index)):
	for col in df.columns: #potential problem, what if the column names are not int
		if isinstance(df.iloc[row,col],str) and "*" in df.iloc[row,col]: 
			allele = df.iloc[row,col]
			gene = allele.split("*")[0]
			if genesHLA not in globals:
                genesHLA = {}
            if gene not in genesHLA:
                genesHLA.update({gene : {}})
			if gene in genesHLA:
				if allele not in genesHLA[gene]:
					genesHLA[gene].update({allele:1})
				else:
					genesHLA[gene].update({allele:genesHLA[gene][allele] +1})

print(genesHLA)
# Out:
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# C
# C
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# DQB1
# DQB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# A
# A
# B
# B
# DRB1
# DRB1
# {'A': {'A*01': 84, 'A*29': 13, 'A*11': 60, 'A*24': 129, 'A*02': 283, 'A*68': 41, 'A*32': 54, 'A*33': 8, 'A*23': 22, 'A*03': 84, 'A*26': 45, 'A*30': 12, 'A*25': 8, 'A*69': 5, 'A*36': 2, 'A*66': 1, 'A*31': 9, 'A*74': 3, 'A*43': 1}, 'B': {'B*07': 50, 'B*44': 58, 'B*55': 22, 'B*35': 112, 'B*51': 143, 'B*18': 136, 'B*40': 39, 'B*08': 43, 'B*14': 7, 'B*54': 3, 'B*37': 26, 'B*13': 20, 'B*52': 22, 'B*27': 25, 'B*78': 4, 'B*15': 25, 'B*38': 23, 'B*41': 11, 'B*53': 9, 'B*50': 11, 'B*39': 21, 'B*49': 14, 'B*57': 13, 'B*58': 12, 'B*56': 2, 'B*47': 7, 'B*45': 2, 'B*48': 1, 'B*73': 2, 'B*82': 1}, 'DRB1': {'DRB1*01': 44, 'DRB1*10': 16, 'DRB1*11': 255, 'DRB1*15': 70, 'DRB1*16': 105, 'DRB1*07': 59, 'DRB1*04': 71, 'DRB1*03': 56, 'DRB1*12': 17, 'DRB1*14': 55, 'DRB1*13': 96, 'DRB1*08': 20}, 'DQB1': {'DQB1*05': 101, 'DQB1*03': 162, 'DQB1*06': 74, 'DQB1*02': 48, 'DQB1*04': 15}, 'C': {'C*02': 27, 'C*03': 18, 'C*06': 28, 'C*12': 31, 'C*07': 68, 'C*04': 48, 'C*16': 9, 'C*15': 35, 'C*05': 23, 'C*14': 12, 'C*01': 12, 'C*08': 3}}

# %%
x= "A*01".split("*")[0]
print(x)
# Out:
# A

# %%
84/864
# Out:
# 0.09722222222222222

# %%
print(locals())
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', '#ParsingHLA\nimport csv\nimport pandas as pd \n\ngenesHLA = {}\n\n# Change current working directory \nloc = ("/Users/anamikabasu/Desktop/AFND0003326.csv") \n\ndf = pd.read_csv("/Users/anamikabasu/Desktop/AFND0003326.csv",header=None)\n\nfor row in range(0,len(df.index)):\n\tfor col in df.columns: #potential problem, what if the column names are not int\n\t\tif isinstance(df.iloc[row,col],str) and "*" in df.iloc[row,col]: \n\t\t\tallele = df.iloc[row,col]\n\t\t\tgene = allele[0].split("*")[0]\n\t\t\tif gene not in genesHLA:\n\t\t\t\tgenesHLA.update({gene : {}})\n\t\t\tif gene in genesHLA:\n\t\t\t\tif allele not in genesHLA[gene]:\n\t\t\t\t\tgenesHLA[gene].update({allele:1})\n\t\t\t\telse:\n\t\t\t\t\tgenesHLA[gene].update({allele:genesHLA[gene][allele] +1})\n\nprint(genesHLA)', 'x= "A*01".split("*")[0]\nprint(x)', '#ParsingHLA\nimport csv\nimport pandas as pd \n\ngenesHLA = {}\n\n# Change current working directory \nloc = ("/Users/anamikabasu/Desktop/AFND0003326.csv") \n\ndf = pd.read_csv("/Users/anamikabasu/Desktop/AFND0003326.csv",header=None)\n\nfor row in range(0,len(df.index)):\n\tfor col in df.columns: #potential problem, what if the column names are not int\n\t\tif isinstance(df.iloc[row,col],str) and "*" in df.iloc[row,col]: \n\t\t\tallele = df.iloc[row,col]\n\t\t\tgene = allele[0].split("*")[0]\n\t\t\tif gene not in genesHLA:\n\t\t\t\tgenesHLA.update({gene : {}})\n\t\t\tif gene in genesHLA:\n\t\t\t\tif allele not in genesHLA[gene]:\n\t\t\t\t\tgenesHLA[gene].update({allele:1})\n\t\t\t\telse:\n\t\t\t\t\tgenesHLA[gene].update({allele:genesHLA[gene][allele] +1})\n\nprint(genesHLA)', '#ParsingHLA\nimport csv\nimport pandas as pd \n\ngenesHLA = {}\n\n# Change current working directory \nloc = ("/Users/anamikabasu/Desktop/AFND0003326.csv") \n\ndf = pd.read_csv("/Users/anamikabasu/Desktop/AFND0003326.csv",header=None)\n\nfor row in range(0,len(df.index)):\n\tfor col in df.columns: #potential problem, what if the column names are not int\n\t\tif isinstance(df.iloc[row,col],str) and "*" in df.iloc[row,col]: \n\t\t\tallele = df.iloc[row,col]\n\t\t\tgene = allele[0].split("*")[0]\n            print(gene)\n\t\t\tif gene not in genesHLA:\n\t\t\t\tgenesHLA.update({gene : {}})\n\t\t\tif gene in genesHLA:\n\t\t\t\tif allele not in genesHLA[gene]:\n\t\t\t\t\tgenesHLA[gene].update({allele:1})\n\t\t\t\telse:\n\t\t\t\t\tgenesHLA[gene].update({allele:genesHLA[gene][allele] +1})\n\nprint(genesHLA)', '#ParsingHLA\nimport csv\nimport pandas as pd \n\ngenesHLA = {}\n\n# Change current working directory \nloc = ("/Users/anamikabasu/Desktop/AFND0003326.csv") \n\ndf = pd.read_csv("/Users/anamikabasu/Desktop/AFND0003326.csv",header=None)\n\nfor row in range(0,len(df.index)):\n\tfor col in df.columns: #potential problem, what if the column names are not int\n\t\tif isinstance(df.iloc[row,col],str) and "*" in df.iloc[row,col]: \n\t\t\tallele = df.iloc[row,col]\n\t\t\tgene = allele[0].split("*")[0]\n\t\t\tprint(gene)\n\t\t\tif gene not in genesHLA:\n\t\t\t\tgenesHLA.update({gene : {}})\n\t\t\tif gene in genesHLA:\n\t\t\t\tif allele not in genesHLA[gene]:\n\t\t\t\t\tgenesHLA[gene].update({allele:1})\n\t\t\t\telse:\n\t\t\t\t\tgenesHLA[gene].update({allele:genesHLA[gene][allele] +1})\n\nprint(genesHLA)', '#ParsingHLA\nimport csv\nimport pandas as pd \n\ngenesHLA = {}\n\n# Change current working directory \nloc = ("/Users/anamikabasu/Desktop/AFND0003326.csv") \n\ndf = pd.read_csv("/Users/anamikabasu/Desktop/AFND0003326.csv",header=None)\n\nfor row in range(0,len(df.index)):\n\tfor col in df.columns: #potential problem, what if the column names are not int\n\t\tif isinstance(df.iloc[row,col],str) and "*" in df.iloc[row,col]: \n\t\t\tallele = df.iloc[row,col]\n\t\t\tgene = allele.split("*")[ ...
# 0      1  A*01  A*29  B*07  B*44  untyped  untyped  DRB1*01  DRB1*10  DQB1*05
# 1      2  A*11  A*24  B*44  B*55     C*02     C*03  DRB1*11  DRB1*15  DQB1*03
# 2      3  A*02  A*68  B*35  B*51  untyped  untyped  DRB1*11  DRB1*11  DQB1*03
# 3      4  A*29  A*32  B*18  B*40  untyped  untyped  DRB1*11  DRB1*16  untyped
# 4      5  A*11  A*32  B*18  B*40  untyped  untyped  DRB1*11  DRB1*16  untyped
# 5      6  A*01  A*33  B*08  B*14  untyped  untyped  DRB1*01  DRB1*07  untyped
# 6      7  A*02  A*33  B*35  B*51  untyped  untyped  DRB1*11  DRB1*16  untyped
# 7      8  A*24  A*24  B*18  B*35  untyped  untyped  DRB1*04  DRB1*11  untyped
# 8      9  A*02  A*23  B*44  B*51  untyped  untyped  DRB1*03  DRB1*04  untyped
# 9     10  A*24  A*24  B*18  B*18  untyped  untyped  DRB1*11  DRB1*12  untyped
# 10    11  A*24  A*24  B*54  B*55  untyped  untyped  DRB1*04  DRB1*11  untyped
# 11    12  A*01  A*68  B*07  B*37  untyped  untyped  DRB1*15  DRB1*16  untyped
# 12    13  A*02  A*02  B*51  B*51  untyped  untyped  DRB1*11  DRB1*11  untyped
# 13    14  A*02  A*11  B*18  B*35  untyped  untyped  DRB1*01  DRB1*11  untyped
# 14    15  A*02  A*24  B*18  B*18  untyped  untyped  DRB1*03  DRB1*11  untyped
# 15    16  A*02  A*02  B*13  B*52     C*06     C*12  DRB1*07  DRB1*14  DQB1*02
# 16    17  A*03  A*26  B*27  B*35  untyped  untyped  DRB1*01  DRB1*11  DQB1*03
# 17    18  A*01  A*29  B*08  B*18  untyped  untyped  DRB1*03  DRB1*14  untyped
# 18    19  A*02  A*02  B*18  B*51  untyped  untyped  DRB1*11  DRB1*14  untyped
# 19    20  A*02  A*29  B*18  B*44  untyped  untyped  DRB1*13  DRB1*16  untyped
# 20    21  A*02  A*23  B*14  B*51  untyped  untyped  DRB1*01  DRB1*04  untyped
# 21    22  A*01  A*03  B*18  B*51  untyped  untyped  DRB1*16  DRB1*16  untyped
# 22    23  A*11  A*24  B*44  B*78  untyped  untyped  DRB1*03  DRB1*14  untyped
# 23    24  A*11  A*32  B*40  B*40  untyped  untyped  DRB1*01  DRB1*16  untyped
# 24    25  A*02  A*02  B*15  B*51  untyped  untyped  DRB1*01  DRB1*14  untyped
# 25    26  A*24  A*29  B*13  B*18  untyped  untyped  DRB1*10  DRB1*15  untyped
# 26    27  A*11  A*32  B*38  B*40  untyped  untyped  DRB1*11  DRB1*15  untyped
# 27    28  A*01  A*02  B*37  B*51  untyped  untyped  DRB1*08  DRB1*16  untyped
# 28    29  A*02  A*24  B*18  B*18  untyped  untyped  DRB1*11  DRB1*15  untyped
# 29    30  A*02  A*24  B*18  B*18  untyped  untyped  DRB1*11  DRB1*14  untyped
# ..   ...   ...   ...   ...   ...      ...      ...      ...      ...      ...
# 402  403  A*02  A*03  B*40  B*55  untyped  untyped  DRB1*11  DRB1*11  untyped
# 403  404  A*02  A*03  B*41  B*51     C*04     C*15  DRB1*11  DRB1*16  untyped
# 404  405  A*01  A*23  B*08  B*44     C*04     C*07  DRB1*07  DRB1*13  untyped
# 405  406  A*02  A*03  B*35  B*35     C*03     C*12  DRB1*11  DRB1*15  untyped
# 406  407  A*03  A*11  B*07  B*35  untyped  untyped  DRB1*01  DRB1*11  untyped
# 407  408  A*11  A*68  B*52  B*55  untyped  untyped  DRB1*15  DRB1*16  untyped
# 408  409  A*01  A*02  B*18  B*37  untyped  untyped  DRB1*11  DRB1*16  untyped
# 409  410  A*24  A*26  B*51  B*51  untyped  untyped  DRB1*01  DRB1*16  untyped
# 410  411  A*02  A*30  B*50  B*58  untyped  untyped  DRB1*08  DRB1*15  untyped
# 411  412  A*02  A*24  B*08  B*18  untyped  untyped  DRB1*07  DRB1*16  untyped
# 412  413  A*24  A*24  B*07  B*44  untyped  untyped  DRB1*01  DRB1*15  untyped
# 413  414  A*02  A*03  B*51  B*55  untyped  untyped  DRB1*03  DRB1*13  untyped
# 414  415  A*11  A*26  B*35  B*47  untyped  untyped  DRB1*10  DRB1*11  untyped
# 415  416  A*02  A*33  B*18  B*35  untyped  untyped  DRB1*07  DRB1*11  untyped
# 416  417  A*03  A*30  B*18  B*35  untyped  untyped  DRB1*11  DRB1*14  untyped
# 417  418  A*02  A*24  B*07  B*51  untyped  untyped  DRB1*04  DRB1*15  untyped
# 418  419  A*02  A*11  B*18  B*35  untyped  untyped  DRB1*04  DRB1*11  untyped
# 419  420  A*03  A*24  B*35  B*51  untyped  untyped  DRB1*14  DRB1*16  untyped
# 420  421  A*03  A*24  B*35  B*51     C*01     C*12  DRB1*11  DRB1*14  untyped
# 421  422  A*01  A*02  B*08  B*51  untyped  untyped  DRB1*03  DRB1*16  DQB1*02
# 422  423  A*02  A*03  B*18  B*18  untyped  untyped  DRB1*11  DRB1*11  DQB1*03
# 423  424  A*23  A*68  B*07  B*18  untyped  untyped  DRB1*11  DRB1*15  untyped
# 424  425  A*02  A*02  B*18  B*40  untyped  untyped  DRB1*04  DRB1*11  untyped
# 425  426  A*02  A*03  B*51  B*51  untyped  untyped  DRB1*04  DRB1*13  untyped
# 426  427  A*02  A*32  B*15  B*18  untyped  untyped  DRB1*08  DRB1*13  untyped
# 427  428  A*26  A*26  B*07  B*38  untyped  untyped  DRB1*11  DRB1*15  untyped
# 428  429  A*02  A*24  B*35  B*51  untyped  untyped  DRB1*04  DRB1*07  untyped
# 429  430  A*02  A*02  B*51  B*51  untyped  untyped  DRB1*11  DRB1*11  untyped
# 430  431  A*02  A*11  B*18  B*35  untyped  untyped  DRB1*01  DRB1*11  untyped
# 431  432  A*01  A*23  B*08  B*27  untyped  untyped  DRB1*03  DRB1*15  untyped
#
#           10
# 0    DQB1*05
# 1    DQB1*06
# 2    DQB1*03
# 3    untyped
# 4    untyped
# 5    untyped
# 6    untyped
# 7    untyped
# 8    untyped
# 9    untyped
# 10   untyped
# 11   untyped
# 12   untyped
# 13   untyped
# 14   untyped
# 15   DQB1*05
# 16   DQB1*05
# 17   untyped
# 18   untyped
# 19   untyped
# 20   untyped
# 21   untyped
# 22   untyped
# 23   untyped
# 24   untyped
# 25   untyped
# 26   untyped
# 27   untyped
# 28   untyped
# 29   untyped
# ..       ...
# 402  untyped
# 403  untyped
# 404  untyped
# 405  untyped
# 406  untyped
# 407  untyped
# 408  untyped
# 409  untyped
# 410  untyped
# 411  untyped
# 412  untyped
# 413  untyped
# 414  untyped
# 415  untyped
# 416  untyped
# 417  untyped
# 418  untyped
# 419  untyped
# 420  untyped
# 421  DQB1*05
# 422  DQB1*03
# 423  untyped
# 424  untyped
# 425  untyped
# 426  untyped
# 427  untyped
# 428  untyped
# 429  untyped
# 430  untyped
# 431  untyped
#
# [432 rows x 11 columns], 'row': 431, 'col': 10, 'allele': 'DRB1*15', 'gene': 'DRB1', '_i2': 'x= "A*01".split("*")[0]\nprint(x)', 'x': 'A', '_i3': '#ParsingHLA\nimport csv\nimport pandas as pd \n\ngenesHLA = {}\n\n# Change current working directory \nloc = ("/Users/anamikabasu/Desktop/AFND0003326.csv") \n\ndf = pd.read_csv("/Users/anamikabasu/Desktop/AFND0003326.csv",header=None)\n\nfor row in range(0,len(df.index)):\n\tfor col in df.columns: #potential problem, what if the column names are not int\n\t\tif isinstance(df.iloc[row,col],str) and "*" in df.iloc[row,col]: \n\t\t\tallele = df.iloc[row,col]\n\t\t\tgene = allele[0].split("*")[0]\n\t\t\tif gene not in genesHLA:\n\t\t\t\tgenesHLA.update({gene : {}})\n\t\t\tif gene in genesHLA:\n\t\t\t\tif allele not in genesHLA[gene]:\n\t\t\t\t\tgenesHLA[gene].update({allele:1})\n\t\t\t\telse:\n\t\t\t\t\tgenesHLA[gene].update({allele:genesHLA[gene][allele] +1})\n\nprint(genesHLA)', '_i4': '#ParsingHLA\nimport csv\nimport pandas as pd \n\ngenesHLA = {}\n\n# Change current working directory \nloc = ("/Users/anamikabasu/Desktop/AFND0003326.csv") \n\ndf = pd.read_csv("/Users/anamikabasu/Desktop/AFND0003326.csv",header=None)\n\nfor row in range(0,len(df.index)):\n\tfor col in df.columns: #potential problem, what if the column names are not int\n\t\tif isinstance(df.iloc[row,col],str) and "*" in df.iloc[row,col]: \n\t\t\tallele = df.iloc[row,col]\n\t\t\tgene = allele[0].split("*")[0]\n            print(gene)\n\t\t\tif gene not in genesHLA:\n\t\t\t\tgenesHLA.update({gene : {}})\n\t\t\tif gene in genesHLA:\n\t\t\t\tif allele not in genesHLA[gene]:\n\t\t\t\t\tgenesHLA[gene].update({allele:1})\n\t\t\t\telse:\n\t\t\t\t\tgenesHLA[gene].update({allele:genesHLA[gene][allele] +1})\n\nprint(genesHLA)', '_i5': '#ParsingHLA\nimport csv\nimport pandas as pd \n\ngenesHLA = {}\n\n# Change current working directory \nloc = ("/Users/anamikabasu/Desktop/AFND0003326.csv") \n\ndf = pd.read_csv("/Users/anamikabasu/Desktop/AFND0003326.csv",header=None)\n\nfor row in range(0,len(df.index)):\n\tfor col in df.columns: #potential problem, what if the column names are not int\n\t\tif isinstance(df.iloc[row,col],str) and "*" in df.iloc[row,col]: \n\t\t\tallele = df.iloc[row,col]\n\t\t\tgene = allele[0].split("*")[0]\n\t\t\tprint(gene)\n\t\t\tif gene not in genesHLA:\n\t\t\t\tgenesHLA.update({gene : {}})\n\t\t\tif gene in genesHLA:\n\t\t\t\tif allele not in genesHLA[gene]:\n\t\t\t\t\tgenesHLA[gene].update({allele:1})\n\t\t\t\telse:\n\t\t\t\t\tgenesHLA[gene].update({allele:genesHLA[gene][allele] +1})\n\nprint(genesHLA)', '_i6': '#ParsingHLA\nimport csv\nimport pandas as pd \n\ngenesHLA = {}\n\n# Change current working directory \nloc = ("/Users/anamikabasu/Desktop/AFND0003326.csv") \n\ndf = pd.read_csv("/Users/anamikabasu/Desktop/AFND0003326.csv",header=None)\n\nfor row in range(0,len(df.index)):\n\tfor col in df.columns: #potential problem, what if the column names are not int\n\t\tif isinstance(df.iloc[row,col],str) and "*" in df.iloc[row,col]: \n\t\t\tallele = df.iloc[row,col]\n\t\t\tgene = allele.split("*")[0]\n\t\t\tprint(gene)\n\t\t\tif gene not in genesHLA:\n\t\t\t\tgenesHLA.update({gene : {}})\n\t\t\tif gene in genesHLA:\n\t\t\t\tif allele not in genesHLA[gene]:\n\t\t\t\t\tgenesHLA[gene].update({allele:1})\n\t\t\t\telse:\n\t\t\t\t\tgenesHLA[gene].update({allele:genesHLA[gene][allele] +1})\n\nprint(genesHLA)', '_i7': 'print(locals())'}

# %%
print(globals())
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', '#ParsingHLA\nimport csv\nimport pandas as pd \n\ngenesHLA = {}\n\n# Change current working directory \nloc = ("/Users/anamikabasu/Desktop/AFND0003326.csv") \n\ndf = pd.read_csv("/Users/anamikabasu/Desktop/AFND0003326.csv",header=None)\n\nfor row in range(0,len(df.index)):\n\tfor col in df.columns: #potential problem, what if the column names are not int\n\t\tif isinstance(df.iloc[row,col],str) and "*" in df.iloc[row,col]: \n\t\t\tallele = df.iloc[row,col]\n\t\t\tgene = allele[0].split("*")[0]\n\t\t\tif gene not in genesHLA:\n\t\t\t\tgenesHLA.update({gene : {}})\n\t\t\tif gene in genesHLA:\n\t\t\t\tif allele not in genesHLA[gene]:\n\t\t\t\t\tgenesHLA[gene].update({allele:1})\n\t\t\t\telse:\n\t\t\t\t\tgenesHLA[gene].update({allele:genesHLA[gene][allele] +1})\n\nprint(genesHLA)', 'x= "A*01".split("*")[0]\nprint(x)', '#ParsingHLA\nimport csv\nimport pandas as pd \n\ngenesHLA = {}\n\n# Change current working directory \nloc = ("/Users/anamikabasu/Desktop/AFND0003326.csv") \n\ndf = pd.read_csv("/Users/anamikabasu/Desktop/AFND0003326.csv",header=None)\n\nfor row in range(0,len(df.index)):\n\tfor col in df.columns: #potential problem, what if the column names are not int\n\t\tif isinstance(df.iloc[row,col],str) and "*" in df.iloc[row,col]: \n\t\t\tallele = df.iloc[row,col]\n\t\t\tgene = allele[0].split("*")[0]\n\t\t\tif gene not in genesHLA:\n\t\t\t\tgenesHLA.update({gene : {}})\n\t\t\tif gene in genesHLA:\n\t\t\t\tif allele not in genesHLA[gene]:\n\t\t\t\t\tgenesHLA[gene].update({allele:1})\n\t\t\t\telse:\n\t\t\t\t\tgenesHLA[gene].update({allele:genesHLA[gene][allele] +1})\n\nprint(genesHLA)', '#ParsingHLA\nimport csv\nimport pandas as pd \n\ngenesHLA = {}\n\n# Change current working directory \nloc = ("/Users/anamikabasu/Desktop/AFND0003326.csv") \n\ndf = pd.read_csv("/Users/anamikabasu/Desktop/AFND0003326.csv",header=None)\n\nfor row in range(0,len(df.index)):\n\tfor col in df.columns: #potential problem, what if the column names are not int\n\t\tif isinstance(df.iloc[row,col],str) and "*" in df.iloc[row,col]: \n\t\t\tallele = df.iloc[row,col]\n\t\t\tgene = allele[0].split("*")[0]\n            print(gene)\n\t\t\tif gene not in genesHLA:\n\t\t\t\tgenesHLA.update({gene : {}})\n\t\t\tif gene in genesHLA:\n\t\t\t\tif allele not in genesHLA[gene]:\n\t\t\t\t\tgenesHLA[gene].update({allele:1})\n\t\t\t\telse:\n\t\t\t\t\tgenesHLA[gene].update({allele:genesHLA[gene][allele] +1})\n\nprint(genesHLA)', '#ParsingHLA\nimport csv\nimport pandas as pd \n\ngenesHLA = {}\n\n# Change current working directory \nloc = ("/Users/anamikabasu/Desktop/AFND0003326.csv") \n\ndf = pd.read_csv("/Users/anamikabasu/Desktop/AFND0003326.csv",header=None)\n\nfor row in range(0,len(df.index)):\n\tfor col in df.columns: #potential problem, what if the column names are not int\n\t\tif isinstance(df.iloc[row,col],str) and "*" in df.iloc[row,col]: \n\t\t\tallele = df.iloc[row,col]\n\t\t\tgene = allele[0].split("*")[0]\n\t\t\tprint(gene)\n\t\t\tif gene not in genesHLA:\n\t\t\t\tgenesHLA.update({gene : {}})\n\t\t\tif gene in genesHLA:\n\t\t\t\tif allele not in genesHLA[gene]:\n\t\t\t\t\tgenesHLA[gene].update({allele:1})\n\t\t\t\telse:\n\t\t\t\t\tgenesHLA[gene].update({allele:genesHLA[gene][allele] +1})\n\nprint(genesHLA)', '#ParsingHLA\nimport csv\nimport pandas as pd \n\ngenesHLA = {}\n\n# Change current working directory \nloc = ("/Users/anamikabasu/Desktop/AFND0003326.csv") \n\ndf = pd.read_csv("/Users/anamikabasu/Desktop/AFND0003326.csv",header=None)\n\nfor row in range(0,len(df.index)):\n\tfor col in df.columns: #potential problem, what if the column names are not int\n\t\tif isinstance(df.iloc[row,col],str) and "*" in df.iloc[row,col]: \n\t\t\tallele = df.iloc[row,col]\n\t\t\tgene = allele.split("*")[ ...
# 0      1  A*01  A*29  B*07  B*44  untyped  untyped  DRB1*01  DRB1*10  DQB1*05
# 1      2  A*11  A*24  B*44  B*55     C*02     C*03  DRB1*11  DRB1*15  DQB1*03
# 2      3  A*02  A*68  B*35  B*51  untyped  untyped  DRB1*11  DRB1*11  DQB1*03
# 3      4  A*29  A*32  B*18  B*40  untyped  untyped  DRB1*11  DRB1*16  untyped
# 4      5  A*11  A*32  B*18  B*40  untyped  untyped  DRB1*11  DRB1*16  untyped
# 5      6  A*01  A*33  B*08  B*14  untyped  untyped  DRB1*01  DRB1*07  untyped
# 6      7  A*02  A*33  B*35  B*51  untyped  untyped  DRB1*11  DRB1*16  untyped
# 7      8  A*24  A*24  B*18  B*35  untyped  untyped  DRB1*04  DRB1*11  untyped
# 8      9  A*02  A*23  B*44  B*51  untyped  untyped  DRB1*03  DRB1*04  untyped
# 9     10  A*24  A*24  B*18  B*18  untyped  untyped  DRB1*11  DRB1*12  untyped
# 10    11  A*24  A*24  B*54  B*55  untyped  untyped  DRB1*04  DRB1*11  untyped
# 11    12  A*01  A*68  B*07  B*37  untyped  untyped  DRB1*15  DRB1*16  untyped
# 12    13  A*02  A*02  B*51  B*51  untyped  untyped  DRB1*11  DRB1*11  untyped
# 13    14  A*02  A*11  B*18  B*35  untyped  untyped  DRB1*01  DRB1*11  untyped
# 14    15  A*02  A*24  B*18  B*18  untyped  untyped  DRB1*03  DRB1*11  untyped
# 15    16  A*02  A*02  B*13  B*52     C*06     C*12  DRB1*07  DRB1*14  DQB1*02
# 16    17  A*03  A*26  B*27  B*35  untyped  untyped  DRB1*01  DRB1*11  DQB1*03
# 17    18  A*01  A*29  B*08  B*18  untyped  untyped  DRB1*03  DRB1*14  untyped
# 18    19  A*02  A*02  B*18  B*51  untyped  untyped  DRB1*11  DRB1*14  untyped
# 19    20  A*02  A*29  B*18  B*44  untyped  untyped  DRB1*13  DRB1*16  untyped
# 20    21  A*02  A*23  B*14  B*51  untyped  untyped  DRB1*01  DRB1*04  untyped
# 21    22  A*01  A*03  B*18  B*51  untyped  untyped  DRB1*16  DRB1*16  untyped
# 22    23  A*11  A*24  B*44  B*78  untyped  untyped  DRB1*03  DRB1*14  untyped
# 23    24  A*11  A*32  B*40  B*40  untyped  untyped  DRB1*01  DRB1*16  untyped
# 24    25  A*02  A*02  B*15  B*51  untyped  untyped  DRB1*01  DRB1*14  untyped
# 25    26  A*24  A*29  B*13  B*18  untyped  untyped  DRB1*10  DRB1*15  untyped
# 26    27  A*11  A*32  B*38  B*40  untyped  untyped  DRB1*11  DRB1*15  untyped
# 27    28  A*01  A*02  B*37  B*51  untyped  untyped  DRB1*08  DRB1*16  untyped
# 28    29  A*02  A*24  B*18  B*18  untyped  untyped  DRB1*11  DRB1*15  untyped
# 29    30  A*02  A*24  B*18  B*18  untyped  untyped  DRB1*11  DRB1*14  untyped
# ..   ...   ...   ...   ...   ...      ...      ...      ...      ...      ...
# 402  403  A*02  A*03  B*40  B*55  untyped  untyped  DRB1*11  DRB1*11  untyped
# 403  404  A*02  A*03  B*41  B*51     C*04     C*15  DRB1*11  DRB1*16  untyped
# 404  405  A*01  A*23  B*08  B*44     C*04     C*07  DRB1*07  DRB1*13  untyped
# 405  406  A*02  A*03  B*35  B*35     C*03     C*12  DRB1*11  DRB1*15  untyped
# 406  407  A*03  A*11  B*07  B*35  untyped  untyped  DRB1*01  DRB1*11  untyped
# 407  408  A*11  A*68  B*52  B*55  untyped  untyped  DRB1*15  DRB1*16  untyped
# 408  409  A*01  A*02  B*18  B*37  untyped  untyped  DRB1*11  DRB1*16  untyped
# 409  410  A*24  A*26  B*51  B*51  untyped  untyped  DRB1*01  DRB1*16  untyped
# 410  411  A*02  A*30  B*50  B*58  untyped  untyped  DRB1*08  DRB1*15  untyped
# 411  412  A*02  A*24  B*08  B*18  untyped  untyped  DRB1*07  DRB1*16  untyped
# 412  413  A*24  A*24  B*07  B*44  untyped  untyped  DRB1*01  DRB1*15  untyped
# 413  414  A*02  A*03  B*51  B*55  untyped  untyped  DRB1*03  DRB1*13  untyped
# 414  415  A*11  A*26  B*35  B*47  untyped  untyped  DRB1*10  DRB1*11  untyped
# 415  416  A*02  A*33  B*18  B*35  untyped  untyped  DRB1*07  DRB1*11  untyped
# 416  417  A*03  A*30  B*18  B*35  untyped  untyped  DRB1*11  DRB1*14  untyped
# 417  418  A*02  A*24  B*07  B*51  untyped  untyped  DRB1*04  DRB1*15  untyped
# 418  419  A*02  A*11  B*18  B*35  untyped  untyped  DRB1*04  DRB1*11  untyped
# 419  420  A*03  A*24  B*35  B*51  untyped  untyped  DRB1*14  DRB1*16  untyped
# 420  421  A*03  A*24  B*35  B*51     C*01     C*12  DRB1*11  DRB1*14  untyped
# 421  422  A*01  A*02  B*08  B*51  untyped  untyped  DRB1*03  DRB1*16  DQB1*02
# 422  423  A*02  A*03  B*18  B*18  untyped  untyped  DRB1*11  DRB1*11  DQB1*03
# 423  424  A*23  A*68  B*07  B*18  untyped  untyped  DRB1*11  DRB1*15  untyped
# 424  425  A*02  A*02  B*18  B*40  untyped  untyped  DRB1*04  DRB1*11  untyped
# 425  426  A*02  A*03  B*51  B*51  untyped  untyped  DRB1*04  DRB1*13  untyped
# 426  427  A*02  A*32  B*15  B*18  untyped  untyped  DRB1*08  DRB1*13  untyped
# 427  428  A*26  A*26  B*07  B*38  untyped  untyped  DRB1*11  DRB1*15  untyped
# 428  429  A*02  A*24  B*35  B*51  untyped  untyped  DRB1*04  DRB1*07  untyped
# 429  430  A*02  A*02  B*51  B*51  untyped  untyped  DRB1*11  DRB1*11  untyped
# 430  431  A*02  A*11  B*18  B*35  untyped  untyped  DRB1*01  DRB1*11  untyped
# 431  432  A*01  A*23  B*08  B*27  untyped  untyped  DRB1*03  DRB1*15  untyped
#
#           10
# 0    DQB1*05
# 1    DQB1*06
# 2    DQB1*03
# 3    untyped
# 4    untyped
# 5    untyped
# 6    untyped
# 7    untyped
# 8    untyped
# 9    untyped
# 10   untyped
# 11   untyped
# 12   untyped
# 13   untyped
# 14   untyped
# 15   DQB1*05
# 16   DQB1*05
# 17   untyped
# 18   untyped
# 19   untyped
# 20   untyped
# 21   untyped
# 22   untyped
# 23   untyped
# 24   untyped
# 25   untyped
# 26   untyped
# 27   untyped
# 28   untyped
# 29   untyped
# ..       ...
# 402  untyped
# 403  untyped
# 404  untyped
# 405  untyped
# 406  untyped
# 407  untyped
# 408  untyped
# 409  untyped
# 410  untyped
# 411  untyped
# 412  untyped
# 413  untyped
# 414  untyped
# 415  untyped
# 416  untyped
# 417  untyped
# 418  untyped
# 419  untyped
# 420  untyped
# 421  DQB1*05
# 422  DQB1*03
# 423  untyped
# 424  untyped
# 425  untyped
# 426  untyped
# 427  untyped
# 428  untyped
# 429  untyped
# 430  untyped
# 431  untyped
#
# [432 rows x 11 columns], 'row': 431, 'col': 10, 'allele': 'DRB1*15', 'gene': 'DRB1', '_i2': 'x= "A*01".split("*")[0]\nprint(x)', 'x': 'A', '_i3': '#ParsingHLA\nimport csv\nimport pandas as pd \n\ngenesHLA = {}\n\n# Change current working directory \nloc = ("/Users/anamikabasu/Desktop/AFND0003326.csv") \n\ndf = pd.read_csv("/Users/anamikabasu/Desktop/AFND0003326.csv",header=None)\n\nfor row in range(0,len(df.index)):\n\tfor col in df.columns: #potential problem, what if the column names are not int\n\t\tif isinstance(df.iloc[row,col],str) and "*" in df.iloc[row,col]: \n\t\t\tallele = df.iloc[row,col]\n\t\t\tgene = allele[0].split("*")[0]\n\t\t\tif gene not in genesHLA:\n\t\t\t\tgenesHLA.update({gene : {}})\n\t\t\tif gene in genesHLA:\n\t\t\t\tif allele not in genesHLA[gene]:\n\t\t\t\t\tgenesHLA[gene].update({allele:1})\n\t\t\t\telse:\n\t\t\t\t\tgenesHLA[gene].update({allele:genesHLA[gene][allele] +1})\n\nprint(genesHLA)', '_i4': '#ParsingHLA\nimport csv\nimport pandas as pd \n\ngenesHLA = {}\n\n# Change current working directory \nloc = ("/Users/anamikabasu/Desktop/AFND0003326.csv") \n\ndf = pd.read_csv("/Users/anamikabasu/Desktop/AFND0003326.csv",header=None)\n\nfor row in range(0,len(df.index)):\n\tfor col in df.columns: #potential problem, what if the column names are not int\n\t\tif isinstance(df.iloc[row,col],str) and "*" in df.iloc[row,col]: \n\t\t\tallele = df.iloc[row,col]\n\t\t\tgene = allele[0].split("*")[0]\n            print(gene)\n\t\t\tif gene not in genesHLA:\n\t\t\t\tgenesHLA.update({gene : {}})\n\t\t\tif gene in genesHLA:\n\t\t\t\tif allele not in genesHLA[gene]:\n\t\t\t\t\tgenesHLA[gene].update({allele:1})\n\t\t\t\telse:\n\t\t\t\t\tgenesHLA[gene].update({allele:genesHLA[gene][allele] +1})\n\nprint(genesHLA)', '_i5': '#ParsingHLA\nimport csv\nimport pandas as pd \n\ngenesHLA = {}\n\n# Change current working directory \nloc = ("/Users/anamikabasu/Desktop/AFND0003326.csv") \n\ndf = pd.read_csv("/Users/anamikabasu/Desktop/AFND0003326.csv",header=None)\n\nfor row in range(0,len(df.index)):\n\tfor col in df.columns: #potential problem, what if the column names are not int\n\t\tif isinstance(df.iloc[row,col],str) and "*" in df.iloc[row,col]: \n\t\t\tallele = df.iloc[row,col]\n\t\t\tgene = allele[0].split("*")[0]\n\t\t\tprint(gene)\n\t\t\tif gene not in genesHLA:\n\t\t\t\tgenesHLA.update({gene : {}})\n\t\t\tif gene in genesHLA:\n\t\t\t\tif allele not in genesHLA[gene]:\n\t\t\t\t\tgenesHLA[gene].update({allele:1})\n\t\t\t\telse:\n\t\t\t\t\tgenesHLA[gene].update({allele:genesHLA[gene][allele] +1})\n\nprint(genesHLA)', '_i6': '#ParsingHLA\nimport csv\nimport pandas as pd \n\ngenesHLA = {}\n\n# Change current working directory \nloc = ("/Users/anamikabasu/Desktop/AFND0003326.csv") \n\ndf = pd.read_csv("/Users/anamikabasu/Desktop/AFND0003326.csv",header=None)\n\nfor row in range(0,len(df.index)):\n\tfor col in df.columns: #potential problem, what if the column names are not int\n\t\tif isinstance(df.iloc[row,col],str) and "*" in df.iloc[row,col]: \n\t\t\tallele = df.iloc[row,col]\n\t\t\tgene = allele.split("*")[0]\n\t\t\tprint(gene)\n\t\t\tif gene not in genesHLA:\n\t\t\t\tgenesHLA.update({gene : {}})\n\t\t\tif gene in genesHLA:\n\t\t\t\tif allele not in genesHLA[gene]:\n\t\t\t\t\tgenesHLA[gene].update({allele:1})\n\t\t\t\telse:\n\t\t\t\t\tgenesHLA[gene].update({allele:genesHLA[gene][allele] +1})\n\nprint(genesHLA)', '_i7': 'print(locals())', '_i8': 'print(globals())'}

# %%
#ParsingHLA
import csv
import pandas as pd 

genesHLA = {}
counts = {}
af = {}

# Change current working directory 
loc = ("/Users/anamikabasu/Desktop/AFND0003326.csv") 

df = pd.read_csv("/Users/anamikabasu/Desktop/AFND0003326.csv",header=None)

for row in range(0,len(df.index)):
    for col in df.columns: #potential problem, what if the column names are not int
        if isinstance(df.iloc[row,col],str) and "*" in df.iloc[row,col]: 
            allele = df.iloc[row,col]
            gene = allele.split("*")[0]
#             if genesHLA not in globals():
#                 genesHLA = {}
            if gene not in genesHLA:
                genesHLA.update({gene : {}})
                counts.update({gene : 0})
            if allele not in genesHLA[gene]:
                genesHLA[gene].update({allele:1})
                counts.update({gene : counts[gene] + 1})
            else:
                genesHLA[gene].update({allele:genesHLA[gene][allele] +1})
                counts.update({gene : counts[gene] + 1})
    
for gene in genesHLA.keys():
    af.update({k:(v/counts[gene]) for (k,v) in genesHLA[gene].items()})


sortedValue = sorted(af.values(), reverse=True)
# Out:
# A
# B
# DRB1
# DQB1
# C

# %%
counts
# Out:
# {'A': 864, 'B': 864, 'DRB1': 864, 'DQB1': 400, 'C': 314}

# %%
counts
# Out:
# {'A': 0, 'B': 0, 'DRB1': 0, 'DQB1': 0, 'C': 0}

# %%
2+2
# Out:
# 4

# %%
84+13+60+129+283+41+54+8+22+84+45+12+8+5+2+1+9+3+1
# Out:
# 864

# %%
27+18+28+31+68+48+9+35+23+12+12+3
# Out:
# 314

# %%
genesHLA.keys()
# Out:
# dict_keys(['A', 'B', 'DRB1', 'DQB1', 'C'])

# %%
af
# Out:
# {'C*02': 0.08598726114649681,
#  'C*03': 0.05732484076433121,
#  'C*06': 0.08917197452229299,
#  'C*12': 0.09872611464968153,
#  'C*07': 0.21656050955414013,
#  'C*04': 0.15286624203821655,
#  'C*16': 0.028662420382165606,
#  'C*15': 0.11146496815286625,
#  'C*05': 0.0732484076433121,
#  'C*14': 0.03821656050955414,
#  'C*01': 0.03821656050955414,
#  'C*08': 0.009554140127388535}

# %%
af = {}
for gene in genesHLA.keys():
    af.update({k:(v/counts[gene]) for (k,v) in genesHLA[gene].items()})

# %%
af
# Out:
# {'A*01': 0.09722222222222222,
#  'A*29': 0.015046296296296295,
#  'A*11': 0.06944444444444445,
#  'A*24': 0.14930555555555555,
#  'A*02': 0.3275462962962963,
#  'A*68': 0.047453703703703706,
#  'A*32': 0.0625,
#  'A*33': 0.009259259259259259,
#  'A*23': 0.02546296296296296,
#  'A*03': 0.09722222222222222,
#  'A*26': 0.052083333333333336,
#  'A*30': 0.013888888888888888,
#  'A*25': 0.009259259259259259,
#  'A*69': 0.005787037037037037,
#  'A*36': 0.0023148148148148147,
#  'A*66': 0.0011574074074074073,
#  'A*31': 0.010416666666666666,
#  'A*74': 0.003472222222222222,
#  'A*43': 0.0011574074074074073,
#  'B*07': 0.05787037037037037,
#  'B*44': 0.06712962962962964,
#  'B*55': 0.02546296296296296,
#  'B*35': 0.12962962962962962,
#  'B*51': 0.16550925925925927,
#  'B*18': 0.1574074074074074,
#  'B*40': 0.04513888888888889,
#  'B*08': 0.04976851851851852,
#  'B*14': 0.008101851851851851,
#  'B*54': 0.003472222222222222,
#  'B*37': 0.03009259259259259,
#  'B*13': 0.023148148148148147,
#  'B*52': 0.02546296296296296,
#  'B*27': 0.028935185185185185,
#  'B*78': 0.004629629629629629,
#  'B*15': 0.028935185185185185,
#  'B*38': 0.02662037037037037,
#  'B*41': 0.01273148148148148,
#  'B*53': 0.010416666666666666,
#  'B*50': 0.01273148148148148,
#  'B*39': 0.024305555555555556,
#  'B*49': 0.016203703703703703,
#  'B*57': 0.015046296296296295,
#  'B*58': 0.013888888888888888,
#  'B*56': 0.0023148148148148147,
#  'B*47': 0.008101851851851851,
#  'B*45': 0.0023148148148148147,
#  'B*48': 0.0011574074074074073,
#  'B*73': 0.0023148148148148147,
#  'B*82': 0.0011574074074074073,
#  'DRB1*01': 0.05092592592592592,
#  'DRB1*10': 0.018518518518518517,
#  'DRB1*11': 0.2951388888888889,
#  'DRB1*15': 0.08101851851851852,
#  'DRB1*16': 0.12152777777777778,
#  'DRB1*07': 0.06828703703703703,
#  'DRB1*04': 0.08217592592592593,
#  'DRB1*03': 0.06481481481481481,
#  'DRB1*12': 0.019675925925925927,
#  'DRB1*14': 0.06365740740740741,
#  'DRB1*13': 0.1111111111111111,
#  'DRB1*08': 0.023148148148148147,
#  'DQB1*05': 0.2525,
#  'DQB1*03': 0.405,
#  'DQB1*06': 0.185,
#  'DQB1*02': 0.12,
#  'DQB1*04': 0.0375,
#  'C*02': 0.08598726114649681,
#  'C*03': 0.05732484076433121,
#  'C*06': 0.08917197452229299,
#  'C*12': 0.09872611464968153,
#  'C*07': 0.21656050955414013,
#  'C*04': 0.15286624203821655,
#  'C*16': 0.028662420382165606,
#  'C*15': 0.11146496815286625,
#  'C*05': 0.0732484076433121,
#  'C*14': 0.03821656050955414,
#  'C*01': 0.03821656050955414,
#  'C*08': 0.009554140127388535}

# %%
genesHLA[gene].items()
# Out:
# dict_items([('A*01', 84), ('A*29', 13), ('A*11', 60), ('A*24', 129), ('A*02', 283), ('A*68', 41), ('A*32', 54), ('A*33', 8), ('A*23', 22), ('A*03', 84), ('A*26', 45), ('A*30', 12), ('A*25', 8), ('A*69', 5), ('A*36', 2), ('A*66', 1), ('A*31', 9), ('A*74', 3), ('A*43', 1)])

# %%
sortedValue = sorted(af.values(), reverse=True)

# %%
sortedKey = sorted(af, key=af.__getitem__, reverse=True)

# %%
sortedValue = sorted(af.values(), reverse=True)

# %%
afSorted = []
for k, v in zip(sortedKey, sortedValue):
    afSorted.append([k,v])
print(afSorted)
# Out:
# [['DQB1*03', 0.405], ['A*02', 0.3275462962962963], ['DRB1*11', 0.2951388888888889], ['DQB1*05', 0.2525], ['C*07', 0.21656050955414013], ['DQB1*06', 0.185], ['B*51', 0.16550925925925927], ['B*18', 0.1574074074074074], ['C*04', 0.15286624203821655], ['A*24', 0.14930555555555555], ['B*35', 0.12962962962962962], ['DRB1*16', 0.12152777777777778], ['DQB1*02', 0.12], ['C*15', 0.11146496815286625], ['DRB1*13', 0.1111111111111111], ['C*12', 0.09872611464968153], ['A*01', 0.09722222222222222], ['A*03', 0.09722222222222222], ['C*06', 0.08917197452229299], ['C*02', 0.08598726114649681], ['DRB1*04', 0.08217592592592593], ['DRB1*15', 0.08101851851851852], ['C*05', 0.0732484076433121], ['A*11', 0.06944444444444445], ['DRB1*07', 0.06828703703703703], ['B*44', 0.06712962962962964], ['DRB1*03', 0.06481481481481481], ['DRB1*14', 0.06365740740740741], ['A*32', 0.0625], ['B*07', 0.05787037037037037], ['C*03', 0.05732484076433121], ['A*26', 0.052083333333333336], ['DRB1*01', 0.05092592592592592], ['B*08', 0.04976851851851852], ['A*68', 0.047453703703703706], ['B*40', 0.04513888888888889], ['C*14', 0.03821656050955414], ['C*01', 0.03821656050955414], ['DQB1*04', 0.0375], ['B*37', 0.03009259259259259], ['B*27', 0.028935185185185185], ['B*15', 0.028935185185185185], ['C*16', 0.028662420382165606], ['B*38', 0.02662037037037037], ['A*23', 0.02546296296296296], ['B*55', 0.02546296296296296], ['B*52', 0.02546296296296296], ['B*39', 0.024305555555555556], ['B*13', 0.023148148148148147], ['DRB1*08', 0.023148148148148147], ['DRB1*12', 0.019675925925925927], ['DRB1*10', 0.018518518518518517], ['B*49', 0.016203703703703703], ['A*29', 0.015046296296296295], ['B*57', 0.015046296296296295], ['A*30', 0.013888888888888888], ['B*58', 0.013888888888888888], ['B*41', 0.01273148148148148], ['B*50', 0.01273148148148148], ['A*31', 0.010416666666666666], ['B*53', 0.010416666666666666], ['C*08', 0.009554140127388535], ['A*33', 0.009259259259259259], ['A*25', 0.009259259259259259], ['B*14', 0.008101851851851851], ['B*47', 0.008101851851851851], ['A*69', 0.005787037037037037], ['B*78', 0.004629629629629629], ['A*74', 0.003472222222222222], ['B*54', 0.003472222222222222], ['A*36', 0.0023148148148148147], ['B*56', 0.0023148148148148147], ['B*45', 0.0023148148148148147], ['B*73', 0.0023148148148148147], ['A*66', 0.0011574074074074073], ['A*43', 0.0011574074074074073], ['B*48', 0.0011574074074074073], ['B*82', 0.0011574074074074073]]

# %%
# import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
